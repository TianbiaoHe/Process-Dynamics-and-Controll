# %%
import numpy as np
from scipy.integrate import odeint
from bokeh.plotting import figure,output_notebook,show

# define the water tanker model
def tanker(h,t,c,valve):
    rho = 1000.0 # kg/m3
    A = 1.0 # m2
    dhdt = (c/(rho*A))*valve
    return dhdt

# time steps
ns = 100
t = np.linspace(0,10,ns)

# initial
h0 = 0.0


# boundary condition
c = 50.0 # kg/s/percent opening
u = np.zeros(ns) # valve opening
u_ub = 100.0
u_lb = 0.0

# P-only control
Kc = 20.0

# storing data for plotting
h = np.zeros(ns)
h[0] = h0

SP = np.ones(ns)*10.0

e = np.zeros(ns)

for i in range(ns-1):
    ts = [t[i],t[i+1]]
    e[i] = SP[i] - h0
    # control output is one step later than the error
    u[i+1] = u[0] + Kc*e[i]
    if u[i+1]>= u_ub:
        u[i+1] = u_ub
    if u[i+1]<= u_lb:
        u[i+1] = u_lb        
    y = odeint(tanker,h0,ts, args=(c,u[i]))
    h0 = y[-1]
    h[i+1] = h0

output_notebook()
p1 = figure(plot_width = 500,plot_height = 400,y_axis_label = 'Level',x_axis_label = 'Time (sec)')
p1.line(t,h,line_width = 3,line_color = 'blue',legend = 'Water Level')


p2 = figure(plot_width = 500,plot_height = 400,y_axis_label = 'Valve',x_axis_label = 'Time (sec)')
p2.line(t,u,line_width = 3,line_color = 'red',line_dash = '4 4')

p3 = figure(plot_width = 500,plot_height = 400,y_axis_label = 'Error',x_axis_label = 'Time (sec)')
p3.line(t,e,line_width = 3,line_color = 'green',line_dash = '4 4')

show(p1)
show(p2)
show(p3)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1edab7ae-7e00-4f8a-a68b-137e34b94b4b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="85e0a712-e437-4eae-ac26-3f0285d098a9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("85e0a712-e437-4eae-ac26-3f0285d098a9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '85e0a712-e437-4eae-ac26-3f0285d098a9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"87d8b3d3-c5a1-47a7-aea3-3fe8861c4af2":{"roots":{"references":[{"attributes":{},"id":"0f3a8dff-8b70-47ff-a930-221f76a7d581","type":"ToolEvents"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1e420b0-a950-4fd4-a6d8-78a8495888f5","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"de3923c6-8700-40b2-abc1-757609bd2170","type":"BoxAnnotation"},{"attributes":{},"id":"477a6610-0a7f-4237-98e9-2a4865779f77","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c8b6e2bd-c16e-4ff6-b584-eab15350ef5b","type":"PanTool"},{"id":"57b2a55c-d197-4ea0-a5c4-f115e03a356c","type":"WheelZoomTool"},{"id":"1e8449f2-958e-4d1e-bf2e-018fb37b5b07","type":"BoxZoomTool"},{"id":"1eea51da-231a-4ce1-b46a-717f12a5f038","type":"SaveTool"},{"id":"76a72a55-f7e1-4719-b2b8-afd0cb8517cf","type":"ResetTool"},{"id":"ef19b492-d569-42b0-ae96-9d64f5e055b2","type":"HelpTool"}]},"id":"cd40ae29-6604-4b8e-a08e-b99a5b33c6af","type":"Toolbar"},{"attributes":{"plot":{"id":"620ba01a-bc47-45e5-947a-b21257ff469c","subtype":"Figure","type":"Plot"}},"id":"ef19b492-d569-42b0-ae96-9d64f5e055b2","type":"HelpTool"},{"attributes":{"plot":{"id":"620ba01a-bc47-45e5-947a-b21257ff469c","subtype":"Figure","type":"Plot"}},"id":"c8b6e2bd-c16e-4ff6-b584-eab15350ef5b","type":"PanTool"},{"attributes":{"callback":null},"id":"7657b013-8296-4980-b8d7-a07010cf6197","type":"DataRange1d"},{"attributes":{},"id":"a54ab072-6389-4642-a90f-8f775f8ca7de","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"620ba01a-bc47-45e5-947a-b21257ff469c","subtype":"Figure","type":"Plot"}},"id":"57b2a55c-d197-4ea0-a5c4-f115e03a356c","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"620ba01a-bc47-45e5-947a-b21257ff469c","subtype":"Figure","type":"Plot"}},"id":"76a72a55-f7e1-4719-b2b8-afd0cb8517cf","type":"ResetTool"},{"attributes":{"plot":{"id":"620ba01a-bc47-45e5-947a-b21257ff469c","subtype":"Figure","type":"Plot"}},"id":"1eea51da-231a-4ce1-b46a-717f12a5f038","type":"SaveTool"},{"attributes":{"callback":null},"id":"5cd8b1aa-3964-4f20-ad68-0c9034f4ba55","type":"DataRange1d"},{"attributes":{"plot":{"id":"620ba01a-bc47-45e5-947a-b21257ff469c","subtype":"Figure","type":"Plot"},"ticker":{"id":"477a6610-0a7f-4237-98e9-2a4865779f77","type":"BasicTicker"}},"id":"73fdbea3-7f52-4dc4-b83e-b6d3af0e8c9b","type":"Grid"},{"attributes":{"overlay":{"id":"de3923c6-8700-40b2-abc1-757609bd2170","type":"BoxAnnotation"},"plot":{"id":"620ba01a-bc47-45e5-947a-b21257ff469c","subtype":"Figure","type":"Plot"}},"id":"1e8449f2-958e-4d1e-bf2e-018fb37b5b07","type":"BoxZoomTool"},{"attributes":{"axis_label":"Time (sec)","formatter":{"id":"b48b08ee-a4a0-4771-87ca-be61a880843f","type":"BasicTickFormatter"},"plot":{"id":"620ba01a-bc47-45e5-947a-b21257ff469c","subtype":"Figure","type":"Plot"},"ticker":{"id":"477a6610-0a7f-4237-98e9-2a4865779f77","type":"BasicTicker"}},"id":"a2e4bbf9-57dd-417c-a4df-0b779b5a7cce","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"620ba01a-bc47-45e5-947a-b21257ff469c","subtype":"Figure","type":"Plot"},"ticker":{"id":"c43e37fe-f8e1-4c40-b1b6-f04fa3b7584a","type":"BasicTicker"}},"id":"f3266dc5-504b-4514-8773-cc9fd2c928fb","type":"Grid"},{"attributes":{"data_source":{"id":"42bc2b51-062c-4885-870b-55173816e6be","type":"ColumnDataSource"},"glyph":{"id":"c1e420b0-a950-4fd4-a6d8-78a8495888f5","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"4c38ce62-07b0-4e48-b09d-9afdc8da3b83","type":"Line"},"selection_glyph":null},"id":"c26ed2a7-ddce-4af6-8b60-32abf9c4fb44","type":"GlyphRenderer"},{"attributes":{},"id":"b48b08ee-a4a0-4771-87ca-be61a880843f","type":"BasicTickF ...
#     <div class="bk-root">
#         <div class="plotdiv" id="66ab0af8-8273-44ac-a1c2-669cc70ff75f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("66ab0af8-8273-44ac-a1c2-669cc70ff75f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '66ab0af8-8273-44ac-a1c2-669cc70ff75f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"46e5e1e6-8314-4f6a-8d7b-8f20b8c2f580":{"roots":{"references":[{"attributes":{"axis_label":"Time (sec)","formatter":{"id":"ef85cca3-6724-4a58-b87e-4e9b8575f073","type":"BasicTickFormatter"},"plot":{"id":"9fbcb241-1aa2-4858-a89f-fd0692a7c10b","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a48f6bb-09cf-4505-9904-6615244aa7fe","type":"BasicTicker"}},"id":"c6a0034c-f52f-4f16-945e-905c37075b4b","type":"LinearAxis"},{"attributes":{"plot":{"id":"9fbcb241-1aa2-4858-a89f-fd0692a7c10b","subtype":"Figure","type":"Plot"}},"id":"c946d898-8d73-4ef3-bcb8-1d6715f93c1e","type":"ResetTool"},{"attributes":{"data_source":{"id":"c92ed7bf-28a8-4a42-b09a-b8d02831641a","type":"ColumnDataSource"},"glyph":{"id":"0ca170d8-f8d8-4020-b0e5-4ae227a2f99f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"0dc77a67-3695-46a6-8f27-71c1fba0860c","type":"Line"},"selection_glyph":null},"id":"dd98f2f5-d461-4bab-8a73-d430b037d238","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"6b0b940d-503a-4835-90ea-ee512e6d7b57","type":"BoxAnnotation"},"plot":{"id":"9fbcb241-1aa2-4858-a89f-fd0692a7c10b","subtype":"Figure","type":"Plot"}},"id":"928a671f-b10b-4e90-a3cc-3fcc0ba2d8b8","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c4baa96d-c260-42f5-abc5-f2f7e0b42000","type":"PanTool"},{"id":"a7ae2bce-718e-4acf-a456-4e6d4be9c4cd","type":"WheelZoomTool"},{"id":"928a671f-b10b-4e90-a3cc-3fcc0ba2d8b8","type":"BoxZoomTool"},{"id":"eb2f01f9-8765-4667-9e37-44484ae5a399","type":"SaveTool"},{"id":"c946d898-8d73-4ef3-bcb8-1d6715f93c1e","type":"ResetTool"},{"id":"e2db5d20-8c0a-4992-9cc8-b28aeabff03b","type":"HelpTool"}]},"id":"124a1e88-819b-4df2-9b81-57ae09b8d6c6","type":"Toolbar"},{"attributes":{},"id":"2d658169-886a-4b41-93af-73dd93e508ea","type":"ToolEvents"},{"attributes":{"plot":{"id":"9fbcb241-1aa2-4858-a89f-fd0692a7c10b","subtype":"Figure","type":"Plot"}},"id":"eb2f01f9-8765-4667-9e37-44484ae5a399","type":"SaveTool"},{"attributes":{"callback":null},"id":"11874f44-7b2d-40b8-81f7-95ef07d6a563","type":"DataRange1d"},{"attributes":{"callback":null},"id":"c4cca391-6a87-4885-bdb0-987c094e8868","type":"DataRange1d"},{"attributes":{},"id":"53241825-00b4-42b9-b212-9604ac1ce6e0","type":"BasicTicker"},{"attributes":{"plot":{"id":"9fbcb241-1aa2-4858-a89f-fd0692a7c10b","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a48f6bb-09cf-4505-9904-6615244aa7fe","type":"BasicTicker"}},"id":"0c6e4213-3cf4-469c-8019-51642f194ae8","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6b0b940d-503a-4835-90ea-ee512e6d7b57","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[4,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"0dc77a67-3695-46a6-8f27-71c1fba0860c","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"9fbcb241-1aa2-4858-a89f-fd0692a7c10b","subtype":"Figure","type":"Plot"},"ticker":{"id":"53241825-00b4-42b9-b212-9604ac1ce6e0","type":"BasicTicker"}},"id":"24b937a3-fb28-4e31-8906-cf66034292f5","type":"Grid"},{"attributes":{"plot":{"id":"9fbcb241-1aa2-4858-a89f-fd0692a7c10b","subtype":"Figure","type":"Plot"}},"id":"e2db5d20-8c0a-4992-9cc8-b28aeabff03b","type":"HelpTool"},{"attributes":{"axis_label":"Valve","formatter":{"id":"b5b9f625-d138-442f-950f-64e26e3e376d","type":"BasicTickFormatter"},"plot":{"id":"9fbcb241-1aa2-4858-a89f-fd0692a7c10b","subtype":"Figure","type":"Plot"},"ticker":{"id":"53241825-00b4-42b9-b212-9604ac1ce6e0","type":"BasicTicker"}},"id":"61d781ad-dfd7-43ab-abc5-7bfd08d29b2a","type":"LinearAxis"},{"attributes":{"plot":{"id":"9fbcb241-1aa2-4858-a89f-fd0692a7c10b","subtype":"Figure","type":"Plot"}},"id ...
#     <div class="bk-root">
#         <div class="plotdiv" id="9c9af4ed-dfac-4893-9ccc-575fa9c64851"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9c9af4ed-dfac-4893-9ccc-575fa9c64851");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9c9af4ed-dfac-4893-9ccc-575fa9c64851' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dca03ae0-1caa-4e02-9509-4b1a60fc6d02":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"80193ca3-b429-455b-bdfa-03a9dc133248","subtype":"Figure","type":"Plot"},"ticker":{"id":"00bf1f15-8a4e-45e9-ab09-56235dfb9539","type":"BasicTicker"}},"id":"0349ecaf-9515-4058-b401-f81301233c11","type":"Grid"},{"attributes":{},"id":"4cf25162-2310-46e5-aa92-f0915a83d875","type":"BasicTicker"},{"attributes":{"line_color":{"value":"green"},"line_dash":[4,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"46714d2e-0c95-45b5-8d92-5829cb38fad8","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f651e035-9b56-4bc6-9bc1-d77fa64ea796","type":"BoxAnnotation"},{"attributes":{},"id":"00bf1f15-8a4e-45e9-ab09-56235dfb9539","type":"BasicTicker"},{"attributes":{"axis_label":"Error","formatter":{"id":"6e2e963a-5577-4aed-a1fb-227804291256","type":"BasicTickFormatter"},"plot":{"id":"80193ca3-b429-455b-bdfa-03a9dc133248","subtype":"Figure","type":"Plot"},"ticker":{"id":"00bf1f15-8a4e-45e9-ab09-56235dfb9539","type":"BasicTicker"}},"id":"d5d2e2a2-a166-44b8-be35-bf5627142290","type":"LinearAxis"},{"attributes":{"plot":{"id":"80193ca3-b429-455b-bdfa-03a9dc133248","subtype":"Figure","type":"Plot"}},"id":"a889a8a8-4ad5-462e-8a78-7d993b83ea11","type":"SaveTool"},{"attributes":{},"id":"5f0acff8-133c-468a-8538-5134afcc1e8d","type":"ToolEvents"},{"attributes":{"plot":{"id":"80193ca3-b429-455b-bdfa-03a9dc133248","subtype":"Figure","type":"Plot"}},"id":"8e509a6c-f00e-4784-aa0f-58bfc48fd6db","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"94a83de6-9828-47ff-ba58-0621a038dde5","type":"PanTool"},{"id":"8e509a6c-f00e-4784-aa0f-58bfc48fd6db","type":"WheelZoomTool"},{"id":"3d7c60c4-6bfa-4af1-9842-c044647b793a","type":"BoxZoomTool"},{"id":"a889a8a8-4ad5-462e-8a78-7d993b83ea11","type":"SaveTool"},{"id":"3cfc5056-8e2e-436f-92e7-ecce7f83a75b","type":"ResetTool"},{"id":"40dadd48-d621-4699-a386-9f6f31068621","type":"HelpTool"}]},"id":"833e7ae2-5963-4224-aab5-f73a5ad1446d","type":"Toolbar"},{"attributes":{"callback":null},"id":"4d6beb42-dcf1-46f7-af7e-347eecaab807","type":"DataRange1d"},{"attributes":{"plot":{"id":"80193ca3-b429-455b-bdfa-03a9dc133248","subtype":"Figure","type":"Plot"},"ticker":{"id":"4cf25162-2310-46e5-aa92-f0915a83d875","type":"BasicTicker"}},"id":"f0c1ef2c-9be2-4547-8204-23e7e128a7a8","type":"Grid"},{"attributes":{"plot":{"id":"80193ca3-b429-455b-bdfa-03a9dc133248","subtype":"Figure","type":"Plot"}},"id":"3cfc5056-8e2e-436f-92e7-ecce7f83a75b","type":"ResetTool"},{"attributes":{},"id":"6e2e963a-5577-4aed-a1fb-227804291256","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"5211a4ba-1fa2-4c88-a873-032ecb0971c9","type":"DataRange1d"},{"attributes":{"axis_label":"Time (sec)","formatter":{"id":"4220df70-50c1-4cb8-b5d8-ec5a38041c71","type":"BasicTickFormatter"},"plot":{"id":"80193ca3-b429-455b-bdfa-03a9dc133248","subtype":"Figure","type":"Plot"},"ticker":{"id":"4cf25162-2310-46e5-aa92-f0915a83d875","type":"BasicTicker"}},"id":"40e9817d-1b3c-44ab-b711-3e8ff89e89c5","type":"LinearAxis"},{"attributes":{},"id":"4220df70-50c1-4cb8-b5d8-ec5a38041c71","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"80193ca3-b429-455b-bdfa-03a9dc133248","subtype":"Figure","type":"Plot"}},"id":"94a83de6-9828-47ff-ba58-0621a038dde5","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,0.10101010101010101,0.20202020202020202,0.30303030303030304,0.40404040404040403,0.5050505050505051,0.6060606060606061,0.7070707070707071,0.8080808080808081,0.9090909090909091,1.0101010101010102,1.1111111111111112,1.2121212121212122,1.313 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>
