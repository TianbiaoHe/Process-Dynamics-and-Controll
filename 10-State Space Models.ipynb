# %%
import numpy as np
from scipy import signal
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# problem 1
A = [-4.0]
B = [2.0]
C = [1.0]
D = [0.0]
sys1 = signal.StateSpace(A,B,C,D)
t1,y1 = signal.step(sys1)

plt.plot(t1,y1)

# %%
# problem 2
A = [[-3.0,0.0],[-2.0,-3.0]]
print(np.linalg.eig(A)[0])
B = [[4.0],[0.0]]
C = [0.5,0.5]
D = [0.0]
sys2 = signal.StateSpace(A,B,C,D)
t2,y2 = signal.step(sys2)

plt.plot(t2,y2)
# Out:
# [-3. -3.]

# %%
# problem 3 
A = [[-0.5,-0.25],[1.0,0.0]]
print(np.linalg.eig(A)[0])
B = [[0.75],[0.0]]
C = [0.0,1.0]
D = [0.0]
sys3 = signal.StateSpace(A,B,C,D)
t = np.linspace(0,30,100)
u = np.zeros(len(t))
u[5:50]= 1.0 # first step input
u[50:] = 2.0 # second step input
t3,y3,x3 = signal.lsim(sys3,u,t)


plt.plot(t,u,'r-')
plt.plot(t3,y3,'b--')
# Out:
# [-0.25+0.4330127j -0.25-0.4330127j]

# %%
# problem 4
A = [[-2.0,-6.0],[-8.0,-8.0]]
print(np.linalg.eig(A)[0])
B = [[8.0],[0.0]]
C = [[0.0,1.0],[1.0,0.0]]
D = [[0.0],[0.0]]
sys4 = signal.StateSpace(A,B,C,D)
t4,y4 = signal.step(sys4)

plt.plot(t4,y4)
# Out:
# [  2.54983444 -12.54983444]
# [<matplotlib.lines.Line2D at 0x1542ca7b908>,
#  <matplotlib.lines.Line2D at 0x1542ca7ba90>]
